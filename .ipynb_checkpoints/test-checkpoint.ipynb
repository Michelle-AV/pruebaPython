# %%
x = 2

# %%
frutas = ["manzana", "banana", "naranja"]
for fruta in frutas:
    print(fruta)  # Esta línea requiere obligatoriamente cuatro espacios o una tabulación
# Out:
# manzana
# banana
# naranja
